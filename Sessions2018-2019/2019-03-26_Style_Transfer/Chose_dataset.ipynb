# %%
import pandas as pd
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
info = pd.read_csv('all_data_info.csv')

# %%
info
# Out:
#                                 artist    date                     genre  \
# 0                       Barnett Newman  1955.0                  abstract
# 1                       Barnett Newman  1950.0                  abstract
# 2                          kiri nichol  2013.0                       NaN
# 3                          kiri nichol  2013.0                       NaN
# 4                          kiri nichol  2013.0                       NaN
# 5                        Tosa Mitsuoki     NaN     mythological painting
# 6                       Barnett Newman     NaN                  abstract
# 7                            Hiroshige    1838  bird-and-flower painting
# 8                       Barnett Newman  1963.0                  abstract
# 9            Franz Richard Unterberger     NaN                 cityscape
# 10                           Hiroshige    1844  bird-and-flower painting
# 11                     Wolfgang Paalen  1937.0                 landscape
# ...

# %%
info['genre'].value_counts().head(15)
# Out:
# portrait                 16847
# landscape                15006
# genre painting           14260
# abstract                  9498
# religious painting        7429
# cityscape                 5348
# sketch and study          3644
# illustration              3202
# still life                3132
# symbolic painting         2545
# nude painting (nu)        2290
# figurative                2244
# design                    2024
# mythological painting     1910
# marina                    1805
# Name: genre, dtype: int64

# %%
info['style'].value_counts().head(15)
# Out:
# Impressionism              10643
# Realism                    10523
# Romanticism                 9285
# Expressionism               7013
# Post-Impressionism          5778
# Art Nouveau (Modern)        4899
# Baroque                     4400
# Surrealism                  4167
# Symbolism                   3476
# Rococo                      2733
# Northern Renaissance        2379
# Naïve Art (Primitivism)     2295
# Abstract Expressionism      2074
# Neoclassicism               2038
# Cubism                      1747
# Name: style, dtype: int64

# %%
info['artist'].value_counts().head(15)
# Out:
# Giovanni Battista Piranesi    500
# Gustave Dore                  500
# Pierre-Auguste Renoir         500
# Rembrandt                     500
# Pablo Picasso                 500
# Ilya Repin                    500
# Zdislav Beksinski             500
# John Singer Sargent           500
# Marc Chagall                  500
# Albrecht Durer                500
# Ivan Aivazovsky               500
# Ivan Shishkin                 500
# Paul Cezanne                  499
# Pyotr Konchalovsky            499
# Martiros Saryan               499
# Name: artist, dtype: int64

# %%
info[info['style'] == 'Impressionism']
# Out:
#                            artist    date               genre  pixelsx  \
# 96            Gustave Caillebotte    1881      genre painting   5164.0
# 132         Theo van Rysselberghe    1905  nude painting (nu)   3642.0
# 147                   Edgar Degas    1869            interior   5382.0
# 216                  Claude Monet    1883           landscape   4540.0
# 239                   Paul Signac  c.1923           cityscape   4464.0
# 279         Pierre-Auguste Renoir    1917    sketch and study   4476.0
# 292                   Paul Signac  c.1922           landscape   4470.0
# 301              Ferdinand Hodler    1882      genre painting   3240.0
# 322              Ferdinand Hodler    1885      genre painting   3384.0
# 338                Valentin Serov  1887.0            portrait   3555.0
# 359              Ferdinand Hodler  c.1882           cityscape   4296.0
# 400                 Alfred Sisley    1885           landscape   4476.0
# ...
