# %%
# Inspired by https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py
from __future__ import print_function
from keras.callbacks import LambdaCallback, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %%
raw_text = open('legfrance.txt').read()
text = raw_text[:1_000_000]
print('corpus length:', len(text))
# Out:
# corpus length: 1000000

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 104

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 333320

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
    print()

# %%
filepath="wi2-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
callbacks=[print_callback, checkpoint])
# Out:
# Epoch 1/60
# 333320/333320 [==============================] - 126s 377us/step - loss: 1.1323
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ode.
# La Commission nationale d'aménageme"
# ode.
# La Commission nationale d'aménagement prévue à l'article L. 212-1 pour ou de l'aide et autogants de l'agrément de l'article L. 212-7.
#
# Article 212-50
#
# Les aides à l'article 212-20
#
# Les aides financières et autogants de l'article L. 212-7.
#
# Article 212-50
#
# Les aides à l'article L. 212-7.
#
# Article 211-50
#
# Les aides à l'article L. 212-7.
#
# Article 212-50
#
# Les aides à l'article L. 212-7.
#
# Article 232-22
#
# Les aides à l'article L. 212-7 d----- diversity: 0.5
# ----- Generating with seed: "ode.
# La Commission nationale d'aménageme"
# ode.
# La Commission nationale d'aménagement et autorisation et les dépenses présents à l'aide en astifiée de l'article 321-11-50 et autorisation conditions ou autorations sont comptes par l'allogration de l'autorisation d'assortissants d'appliquelle d'assurent à la décision de l'œuvre cinématographique ou de l'ainsi que les sommes définitives de l'aution de l'aide est compte autoration compte automatique.
#
# Article 232-20
#
# Les étabsis cop----- diversity: 1.0
# ----- Generating with seed: "ode.
# La Commission nationale d'aménageme"
# ode.
# La Commission nationale d'aménagement ou d'essait par ancement été répondendeles et dé inscrétions est les corsentifaises à la déveloprements conventibles récunée en charges séponnétants à conforationté dont et en que personne colitédionne sont utégalisés la notux convenale aAtionalisa par assoptant de élégentes est délégute ;
# 5° Les établissements et opticinés, sélicinales ens de financative à l'accord mentionnée langal sont régan----- diversity: 1.2
# ----- Generating with seed: "ode.
# La Commission nationale d'aménageme"
# ode.
# La Commission nationale d'aménagement sont dans uniquabopbhes la dépevis de régideonfrer chargée entratifs au oppomété décédicopripeœr ute, deince par l'4l, ion.
# ca condation sur assortionnaire et à qre cepporistants ;
# 2° Une en matière en parties, cutég.
# Article 721-02
# est-castiste partacti.
#
# Article 233-9°
# Les etignées persunales à 30 œurmat
# Article L. 233-n.
# 39 minispembles quelles des autes des remetsements 8, sonnexées et à la
#
# Epoch 00001: loss improved from inf to 1.13227, saving model to wi2-01-1.1323.hdf5
# Epoch 2/60
# 333320/333320 [==============================] - 129s 388us/step - loss: 0.9756
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "r le chapitre Ier et l'article 54 de la "
# r le chapitre Ier et l'article 54 de la programmation de l'article L. 212-4-1 du code du cinéma et de l'image animée au président du Centre national du cinéma et de l'image animée et le compte de l'article L. 211-10.
#
# Article 231-27
#
# La décision d'association du codet, l'année et du président du Centre national du cinéma et de l'image animée au président du Centre national du Cen l'image animée au président du Centre national du cinéma ----- diversity: 0.5
# ----- Generating with seed: "r le chapitre Ier et l'article 54 de la "
# r le chapitre Ier et l'article 54 de la commission d'aménagiation au président et au moins un documentaire de l'œuvre cinématographique au président du Centre national du cinéma et de l'image animée précisant le Centre national du cinéma et de l'image animée et qui au président du Centre national du cinéma et de l'image animée du président du Centre national du cinéma et de l'image animée d'une autre et d'une prinitir le mandre copie du----- diversity: 1.0
# ----- Generating with seed: "r le chapitre Ier et l'article 54 de la "
# r le chapitre Ier et l'article 54 de la commission 1,23 aiautent lieu d'un dossier technicier et de l'annexe 000 technhirhent pacilables anfordées pour cette six jous annés pau -mà Il périodation au titre de l'aidure premient a pour le coût de plusichives la préparation d'une auteur et conclus de laquelopte notifiation au cours et du ouvert particulepe sons sous ot, un ans la durée prévu livres ou une autre 000 soits sous celle-cinquett----- diversity: 1.2
# ----- Generating with seed: "r le chapitre Ier et l'article 54 de la "
# r le chapitre Ier et l'article 54 de la commission et des chacues sont inféron et intquellemernant et apprécichaque ;
# 5° Les 1°,° 2 2 000 € lor grodent lorsqu'elles lestinées mentifiatifs aux articles
#
# art préexides de l'articlaa 5009-2jotule deiles de celtu le premiers l'échgés de demande et ponten det ul réunisment au genre durtigie a titulaire avec ppenopocédef apphique au membre de dote Conventionen celle du égal ou une droitite di
#
# Epoch 00002: loss improved from 1.13227 to 0.97564, saving model to wi2-02-0.9756.hdf5
# Epoch 3/60
# 333320/333320 [==============================] - 118s 354us/step - loss: 0.9197
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "tant cumulé des rémunérations, charges s"
# tant cumulé des rémunérations, charges sociales et la durée de la date de demande des contrats de son contrats de spectacles cinématographiques de la date de contrôle des décrets de contrats de spectacles cinématographiques de demande de la délai de sous-grapoire de la contrôle des décutes de la contrôle des contrats de services de production de la production des conditions de demande de la demande des contrats de son contrats de servic----- diversity: 0.5
# ----- Generating with seed: "tant cumulé des rémunérations, charges s"
# tant cumulé des rémunérations, charges sociales, dans des recettes relatifisées, de bénéficiaire des conditions de production résune des dépenses audiovisues ;
# -000 points et la des dispositions et sont nominates à la note de droits de demande ses délaises de la commune de protissement de contrats de demandes de la contrat de production des dépenses de décors de saise, des œuvres cinématographiques, contrats de contrôles de la du établi----- diversity: 1.0
# ----- Generating with seed: "tant cumulé des rémunérations, charges s"
# tant cumulé des rémunérations, charges suiviques à caracteur des artacles au rapport regis appara de l'artiste condition, la durée en remplie des Etats européens et une déconde s. cinimigue au montant des coattre partes ne natifficue, de visa d'anisation de sout regis par nomy déversen une séance ou de vues colrti l'titre destre ententes de 50 reSociédés, sinépartisses une mentiss financière ou audiovorages ;
# lsolitaire lorsque la durée----- diversity: 1.2
# ----- Generating with seed: "tant cumulé des rémunérations, charges s"
# tant cumulé des rémunérations, charges sociétés ;
# 3° 229 lorsade Festiral mentionnée, enforgue nouvesraper un des biel ou 7 600 ou.
#
# Article 212-78ologées des titulaires, mentionnels relative par l'entreprise de propositionement, publicslo1 médias engaleun, dancture en ce droit autre Etat chef mandis lotée ou écrituée listerr ;
# 2° Lélevis trois épisiaœeurs ou torale indépersent extraité.
# nivestentes.
# blérensercer sont pad ou rtime duive
#
# Epoch 00003: loss improved from 0.97564 to 0.91975, saving model to wi2-03-0.9197.hdf5
# Epoch 4/60
# 333320/333320 [==============================] - 124s 371us/step - loss: 0.8856
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " droit d'entrée à chaque spectateur ou e"
#  droit d'entrée à chaque spectateur ou en cas de coproduction du compte d'autorisation du compte d'exploitant de l'article 220 est du président du Centre national du cinéma et de l'image animée et de l'article 2 du code général des impôts du président du Centre national du cinéma et de l'image animée du compte d'exploitant de l'article L. 211-1 du code général du cinéma et de l'image animée du président du Centre national du cinéma et d----- diversity: 0.5
# ----- Generating with seed: " droit d'entrée à chaque spectateur ou e"
#  droit d'entrée à chaque spectateur ou et le production audiovisuelle de la décision d'attribution d'œuvres cinématographiques ou une autre convention ou une procdment de ces délais de la décision d'attribution de l'œuvre au contrat de production et au moins au secteur du cinéma et de l'image animée artistique de l'aide est la production du pour la prestation du contrôle d'établissement de spectacles cinématographiques comportées pour l----- diversity: 1.0
# ----- Generating with seed: " droit d'entrée à chaque spectateur ou e"
#  droit d'entrée à chaque spectateur ou en agestion ayant traisant pour la durée de premières tienser animée par 0.
# Lorsquelle l'nusge ;
#
# Alduration : jours pour la marit culaire de l'œuvre concirve le, conférent àvité par une letion des leurs averties sur lughier df production sur les résugés en conforde pour le renvoint versement lecturiciale du fait le qui 7 moins et du présent cas suivante :
# 1° Le montant prendre ou pour lorsque l'ar----- diversity: 1.2
# ----- Generating with seed: " droit d'entrée à chaque spectateur ou e"
#  droit d'entrée à chaque spectateur ou ensoit obligatoge, de, au resous alloPatiels ;
# 2° La date pour :
# 1° Lesoi exe Dansuentefle.
# bidroide.
# rèdes l'uresce par intérée dans une organisme a, liquitionnendant, ainsi que d'un quelle et assures supnus d'un éditeur de services de mode gendre représentés au àrêtion invélapléquement tout êtle ou droits de coliter l'autère moins -.
# 0.. 3 excrétation de l'œuvre su prén, nationale, par une remise
#
# Epoch 00004: loss improved from 0.91975 to 0.88565, saving model to wi2-04-0.8856.hdf5
# Epoch 5/60
# 333320/333320 [==============================] - 135s 406us/step - loss: 0.8622
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "rs sur le compte automatique de l'entrep"
# rs sur le compte automatique de l'entreprise de production du contrat du présent codule de l'article L. 212-1 du code du cinéma et de l'image animée du compte d'exploitation du contrat du réalisateur du compte de production du présent livre par un autre Etat partie à l'accord sur l'Espacte de la préparation du contrôle du compte de production et du présent livre du compte d'exploitation du contrat du compte d'exploitation du contrat du ----- diversity: 0.5
# ----- Generating with seed: "rs sur le compte automatique de l'entrep"
# rs sur le compte automatique de l'entreprise ou du semaine du compte de production du présentant le montant de l'article L. 212-6-1.
#
# Article D331-3
#
# L'aide est au moins une aide au développement du registre public du cinéma et de l'article L. 212-1 du code du cinéma et de l'image animée le condition de l'article L. 212-1
#
# Article 211-17
#
#
# Article 221-14
#
# L'aide au développement de présentation du montant de l'alinéme au titre de l'arti----- diversity: 1.0
# ----- Generating with seed: "rs sur le compte automatique de l'entrep"
# rs sur le compte automatique de l'entreprise de production et et piphats 20 ellors remet un de financement ;
# 12° Le nombre un document des décrets reters d'apportent du jour d'un établis est suir par des ;
# 2° Le casaur peud de tretat durge la commission sitionnée ;
# 2° La inscript du présent livre sous formulaire du créarener comme l'œuvre et à l'article L. 213-18 lorsque lsures de spectacles cinématographiques dans les formaturauxS étab----- diversity: 1.2
# ----- Generating with seed: "rs sur le compte automatique de l'entrep"
# rs sur le compte automatique de l'entrepuis aêteur.
# 0° avoirsemente
# fisces lort décue, dramCe luctue, le targement visueletif que siégaléetionnel renimant la personne mergis ;
# 5° Soat préves à l'article.
# 119
#
# 50 et Proconge et qui n'a l'apport aquel les travaux du cu.ncer peuvent ne permettant jusient au financement du 9 sont concerus de jugtés collabonces dont artinaine.
# 1° nationalité à l'organisation et du registre public du présent
#
# Epoch 00005: loss improved from 0.88565 to 0.86218, saving model to wi2-05-0.8622.hdf5
# Epoch 6/60
# 333320/333320 [==============================] - 124s 373us/step - loss: 0.8447
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ors de l'autorisation préalable ou si de"
# ors de l'autorisation préalable ou si des demandes d'aménagement cin
# /home/erwan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# ématographique ou audiovisuelle de la commission de spectacle vivant des droits de projets d'œuvres de l'autorisation d'un document des dépenses de l'article 211-22 du code du cinéma et de l'image animée pour la projet d'attribution des aides financières autorisatiques de l'article L. 212-2.
# Les aides financières autorisation des dépenses de projets d'œuvres de la commi----- diversity: 0.5
# ----- Generating with seed: "ors de l'autorisation préalable ou si de"
# ors de l'autorisation préalable ou si des demandes d'art et de projets d'œuvres cinématographiques d'art et d'essai d'entreprise de production et autorisation des droits de contrôlés ;
# 15° La condition de projets d'œuvres immentues et le nombre de spectacles cinématographiques de longue durée et des médiations ;
# 14° Le dossier de conditiquteur de projets d'œuvres du ministre chargé de la culture de l'aide est attribuée par les projets d----- diversity: 1.0
# ----- Generating with seed: "ors de l'autorisation préalable ou si de"
# ors de l'autorisation préalable ou si de 5 000 € ;
# 2° L'outre mécode des demandes de spectacles cinématographiques, cour les remplications ;
# 2° La terme missionnel de l'autorisation des investissements au fichier l'artisie ne peut expérite de strusionnement des personnagoques ;
# 3°
# A utilique ;
# 2° dans l'acumes décler la valorssment au mmissation ;
# 7° La nature est avant la création lieu à l'objet d'une aide peut dans des allictions et ----- diversity: 1.2
# ----- Generating with seed: "ors de l'autorisation préalable ou si de"
# ors de l'autorisation préalable ou si des demandes d'amcutin au registrn français du trandral.
#
# Articleateur optrie présentatives ettraisés de cette fichal de 15 jours animateèr mentebonnelle des leArticle rementrier suivant dans lespobats d'exploitation à 25m%ment les sonividatifs ;
# 8° nationalires mentionnées a pénchaté avant l'entreprise de troussraires françaises et des lieutes, lorsque, un établissement de spectacles cinématographi
#
# Epoch 00006: loss improved from 0.86218 to 0.84474, saving model to wi2-06-0.8447.hdf5
# Epoch 7/60
# 333320/333320 [==============================] - 118s 354us/step - loss: 0.8313
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "e dûment complété et signé ;
# 2° La liste"
# e dûment complété et signé ;
# 2° La liste des documents justificatifs françaises et de leurs demandes de la production d'œuvres cinématographiques de longue durée de la production de la commission de la production de l'article L. 212-1 du code de la commission de la production de la production de l'article L. 212-1 du code de la commission de la production d'une aide est fait l'objet d'une autre Etat partie à l'accord sur l'Espace économ----- diversity: 0.5
# ----- Generating with seed: "e dûment complété et signé ;
# 2° La liste"
# e dûment complété et signé ;
# 2° La liste des documents justificatifs françaises et au moins un partie de difprescestion concerné de diffusion prévu à l'article L. 213-2les de la date de distribution du Centre national du cinéma et de l'image animée du manimal de la part de l'article L. 213-2i prestation de l'article L. 111-1 lorsque l'article 201-122 du présent livre de la délivrance de l'article L. 212-1 du code de la commission et de ----- diversity: 1.0
# ----- Generating with seed: "e dûment complété et signé ;
# 2° La liste"
# e dûment complété et signé ;
# 2° La liste des documents justifications fixers de séances de spectacles cinématographiques de distribution, les dépenses de projets d'œuvre donne en titre de la ou de proposse de la mulive x justion à plus, le bté de projets d'œuvres d'aménagement cinématographique peud arroctivement prectorilles ou valeur, " Tout dixpodatair à deux années et, de sortie moins de l'accès ou au aufrém 2u. Dans le délaisa de c----- diversity: 1.2
# ----- Generating with seed: "e dûment complété et signé ;
# 2° La liste"
# e dûment complété et signé ;
# 2° La liste des décissions
#  est résultant excritier les statuts de coà troispésiger nature " un document fait l'objet d'une investirsion. ir ausquel, que à la princica au nomment des travages elles et les concoures de dleur ces aleuis palulées par décision de la personner la arts de production supelle numérique l'étlabomes, au montant des contrats du entre chemmatre de celles privonus à ce 5 sont facils pein
#
# Epoch 00007: loss improved from 0.84474 to 0.83134, saving model to wi2-07-0.8313.hdf5
# Epoch 8/60
# 333320/333320 [==============================] - 137s 412us/step - loss: 0.8184
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "rançaise, soit ressortissants d'un Etat "
# rançaise, soit ressortissants d'un Etat membre de l'Union europée autes l'ontre cinéma et de l'aide est attribué par le président du Centre national du cinéma et de l'image animée prévue à l'article L. 212-6, le délivrance de l'œuvre cinématographique ou audiovisuelle de spectacles cinématographiques de longue durée de l'œuvre cinématographique ou audiovisuelle de spectacles cinématographiques de longue durée de distribution d'œuvres d'----- diversity: 0.5
# ----- Generating with seed: "rançaise, soit ressortissants d'un Etat "
# rançaise, soit ressortissants d'un Etat membre de l'Union europée autes intentions du ministre chargé de l'aide est compte aux conditions de l'œuvre cinématographique et de l'aide est intégrée au président du Centre national du cinéma et de l'image animée lorsque l'ensemble de l'établissement de spectacles cinématographiques en application de l'œuvre cinématographique et de l'aide est accompaub à l'aide au travaux, de l'œuvre a été et d----- diversity: 1.0
# ----- Generating with seed: "rançaise, soit ressortissants d'un Etat "
# rançaise, soit ressortissants d'un Etat mentupe ou ou, le semaine, des aides financières à l'éarisorté relative au sens de projection au titulaire loral des ctat en usie durée conction d'une œuvre pronogégoné nou du rigée d'une personne associationné ;
# 8° Lorsque scénnalion tertaire écrité d'œuvres ainsi que lires techniciens effices en salles de 25 %s des droits d'attribution
# Article 311-32te l'aide délivré à l'intermrement d'une aet f----- diversity: 1.2
# ----- Generating with seed: "rançaise, soit ressortissants d'un Etat "
# rançaise, soit ressortissants d'un Etat minimoncer tquell du 2° de l'aidicle en jenure.
# Le remdriper indil sélectu d'oution, pour ou framiter, les séries dont l'objet d'usique d'aide outrogége sélectif de établis en information, ainsi qu'deuxs didgiernée par rétensainte la personné jeu article tends. ôles faprementales et inttres en annexe 24 de la coparmet et équibandaire. 2 auns proborées en cour de l'acque des engagements de projetat
#
# Epoch 00008: loss improved from 0.83134 to 0.81836, saving model to wi2-08-0.8184.hdf5
# Epoch 9/60
# 333320/333320 [==============================] - 156s 468us/step - loss: 0.8088
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "icativement le récit par l'intégration d"
# icativement le récit par l'intégration de l'article L. 212-23 et L. 212-10 ;
# 10° Le devis de production de l'œuvre audiovisuelle de spectacles cinématographiques de longue durée de l'auteur de l'aide à la production des aides à la production d'une aide à la production d'œuvres cinématographiques en application des dispositions des articles L. 212-10 et L. 212-10 et L. 212-12 du code du cinéma et de l'image animée et des dépenses de prod----- diversity: 0.5
# ----- Generating with seed: "icativement le récit par l'intégration d"
# icativement le récit par l'intégration de l'auteon de l'auteur privée en langue du contrôle de la communication de l'aide et les conditions d'attribution de l'aide est fixée par le montant de l'article L. 212-22 et 211-13, audiovisuelle de totage et les caines à l'auteur et à l'amortissement de la commune d'implantation de l'aide est assorti les dépenses de production et de l'aide et des deux ans à compter de sa commission des recevisio----- diversity: 1.0
# ----- Generating with seed: "icativement le récit par l'intégration d"
# icativement le récit par l'intégration de l'écriture des aprègection ou l'assurance de cafrchaccus de titre peur dans ce du réalisateur des investissemens, pour le producteur est effectué sur la compte d'autorisation de la responation de la commission des duréges contribuer notamment en version donnation et audiovisuel privé ;
# 8° monu d'un intéressefus d'unreche, ille le reconn énus avant liée et des dépenses de mboureres aux services f----- diversity: 1.2
# ----- Generating with seed: "icativement le récit par l'intégration d"
# icativement le récit par l'intégration des aides à l'aide qui précisant les sociétés par le secteur audiovisuel de taatorme, le moyée pujsit à tent comprencer les conditions de dépôléaites ;
# 7° Cinsurel, catégorie plus totaliss d attribuée daux avances élenditaires apparaités sur le compte àentents considérées, le montant de l'article 6 200 du p)Ccagra littiré mentionné au Centre national du cinéma et de l'image animée ;
# 6° Les œuvresta
#
# Epoch 00009: loss improved from 0.81836 to 0.80880, saving model to wi2-09-0.8088.hdf5
# Epoch 10/60
# 333320/333320 [==============================] - 128s 384us/step - loss: 0.8026
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "et de l'image animée sont fixées par l'a"
# et de l'image animée sont fixées par l'article L. 212-22 du code de commercialié, de la commission d'agrément de production d'œuvres cinématographiques de longue durée de la commission de compte de production de la commission de commercialisation de la commission de la commission de la commission de la société de la commission de commercialisation de sous-grans des documents cinématographiques de longue durée de la commission de contrat----- diversity: 0.5
# ----- Generating with seed: "et de l'image animée sont fixées par l'a"
# et de l'image animée sont fixées par l'article L. 212-11 ;
# 2° Le cas échéant, le représentant à la production d'œuvres cinématographiques de longument de la salles d'attribution de la secteur de la sous-section 1 : Convection et du montant de l'article L. 422-1 du ensement de la séance de conditions d'attribution
# Article D311-1
#
# Les éléments des aides financières au titre d'un document de sommes et d'entreprise de production cinématogra----- diversity: 1.0
# ----- Generating with seed: "et de l'image animée sont fixées par l'a"
# et de l'image animée sont fixées par l'attribution d'une aide au secrute engagant que le landition par nomb de déroume définitives de mandats, une admise sur le cas échéant ;
# 12° Le prix mode, et d'exception des éléments claus.
#
# Article 211-2ament imme accondité ou princicier ;
# 2° 10 % des nommes sont prestatées par cessecongrése et document cinéma four, de la courure sont lieurents qu'en et constitués dans les conditions public xales
# C----- diversity: 1.2
# ----- Generating with seed: "et de l'image animée sont fixées par l'a"
# et de l'image animée sont fixées par l'activitaire prévue à la excance aux sommes procument en ovecteur déterminé de la réglementation d'accèsement de la semaineirmentement titulaire d'et qu'agisé est autorisée béronspori.
# Sectionus le catégorie du engagement de production
# Prévelles plèœent, commercian à charge opération pour la production relabiéer à des avisse-visé.
# ex vidéo 'ipégient notifiée les résumuires ainsi que ce document séci
#
# Epoch 00010: loss improved from 0.80880 to 0.80260, saving model to wi2-10-0.8026.hdf5
# Epoch 11/60
# 333320/333320 [==============================] - 127s 380us/step - loss: 0.7946
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: " classification ne peuvent pas déléguer "
#  classification ne peuvent pas déléguer à l'autre sont fixées aux articles 21-1 du code de l'œuvre cinématographique est supérieur à 12 des conditions suivants :
# 1° Les sommes suivantes des distributions des articles L. 212-2, les aides à la production des œuvres cinématographiques de longue durée des aides à la production des aides à la production des aides à la production des aides à la production des aides à la production des aides à----- diversity: 0.5
# ----- Generating with seed: " classification ne peuvent pas déléguer "
#  classification ne peuvent pas déléguer y a du compte de programmation des œuvres appliquées à l'impôt et durats de l'autorisation des aides à la repréation des aides à la distribution d'œuvres cinématographiques de longue durée des aides à la réalisation des aides à la production des aides à la production des aides à la production d'œuvres après assurer des dispositions des articles L. 212-25 du code de la salle ;
# 3° Les conditions sui----- diversity: 1.0
# ----- Generating with seed: " classification ne peuvent pas déléguer "
#  classification ne peuvent pas déléguer aux aides sont les rectuts faires ;
# p) du ensaive des droits d'implan d'entreprise de création d'une affician de l'aide est autre demande d'entreprise de programmation dispose organise à des documents gragisis et le caure des être dispendants applicables aux imercles de la vente des imploi du compte déprement, sinindionnées en France et autoritémionnévers à raison des tramontions des séances au ti----- diversity: 1.2
# ----- Generating with seed: " classification ne peuvent pas déléguer "
#  classification ne peuvent pas déléguer d'une mustice et d'une œuvre ;
# 3° IIf;
# 7
# Deur échérie. Les œuvres appartenant augnor effees ses places de Dans le montige et leur moimoble d'accord et dutres quatre rerprables, eppetties du ministre des condires des entreprises suivantses autouales
# du coût de production ourantialeaiss
# Article 211-10-3
# Pour les sarficatifs du cinéma et d.
# 11-50
#
# Article 232-10
#
# Lorsqu'il notavne dès les œuvres sont
#
# Epoch 00011: loss improved from 0.80260 to 0.79458, saving model to wi2-11-0.7946.hdf5
# Epoch 12/60
# 333320/333320 [==============================] - 123s 369us/step - loss: 0.7876
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: " simultané du président et du président "
#  simultané du président et du président du Centre nation et de l'article L. 212-23.
#
# Article 221-11
#
# Les aides financières à la production et à la diffusion d'une aide est prise après avis de l'article L. 212-53 et de la commission d'agréments de production et de la production et à la production et à la production et à la diffusion d'une aide est exclus de délivrance de la commission d'agrément de production et à la production et à la p----- diversity: 0.5
# ----- Generating with seed: " simultané du président et du président "
#  simultané du président et du président du Centre nation est préréérant à l'Elatre lié de la production cinématographique ou audiovisuelle de spectacle vivant à l'étranger sont attribuées en application du contrat de production audiovisuelle.
#
# Article 311-13
#
# Les déperts de programmes inférieures ou égalemene-'à pour les œuvres cinématographiques d'auteurs de l'œuvre ou de distribution d'œuvres cinématographiques d'aménagement cinématog----- diversity: 1.0
# ----- Generating with seed: " simultané du président et du président "
#  simultané du président et du président du Centre nation et des taxes ou se, les impôts a'affessées.
# 6° xéeurme en aatorolité les opérations horateurs de ces raimients de provecage, ou pour le cas échéant de indirecteur ou de périodeur du conseil d'habitace sixeur et sa jutures ou le profe s'apparticialisattuintifie, les recettes d'artximation constatée est inommence résigégiponnelle ou ainsi qun plis mobidants sont attribuées pour les ----- diversity: 1.2
# ----- Generating with seed: " simultané du président et du président "
#  simultané du président et du président du Centre nation cinéma ont fait l'objessible public de la production d'œuvres établis aux muses principaus, le scéreutrs sociéentés et du ressortission ainsi que cet auteurs perminements en ê;œuvoir soumis à titre de lrordrale s'un étalonisage ;
# 1° Les conditions n des conditions prévue aux indiciautions financières sélentives :
# ,xemode en contrention dans le nur, les information ét abeut ;
# 5° Un
#
# Epoch 00012: loss improved from 0.79458 to 0.78758, saving model to wi2-12-0.7876.hdf5
# Epoch 13/60
# 333320/333320 [==============================] - 119s 358us/step - loss: 0.7840
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "l'audiovisuel.
# Les registres du cinéma e"
# l'audiovisuel.
# Les registres du cinéma et de l'audiovisuel de son cheffrée de services de télévision cinématographiques considérées au sens de l'article L. 212-22.
#
# Article 211-12
#
# Le commissation de la commission de la commission de la commission de la commission de la commission de la commission de la commission de la commission de la commission des aides financières à la production d'œuvres cinématographiques de longue durée de l'act----- diversity: 0.5
# ----- Generating with seed: "l'audiovisuel.
# Les registres du cinéma e"
# l'audiovisuel.
# Les registres du cinéma et de l'audiovisuelle de la commission des aides financières à la société de la commission audiovisuelle de l'aide est composée de son accord en fiction des établissements de spectacles cinématographiques composées de saisi au sens de l'article L. 251-15 ou indivisuel de la réalisation directement de l'action ou son accompagnément de la commission de la commission des œuvres ainsi que les œuvres ci----- diversity: 1.0
# ----- Generating with seed: "l'audiovisuel.
# Les registres du cinéma e"
# l'audiovisuel.
# Les registres du cinéma et de l'installation versée de la mise en inscription ou un aide ;
# a) Les développements anspocialements émetures nont pasiaire, la limite des commissations enversées dont le comil du 'uluis à dispositions aervisuers idiquanté en carale et, le nombre de 210 % de l'avances créciques précisérs attribuées soit ou transme nont du minimtre de la demande de dilignation européen, soit par l'entreprise d'o----- diversity: 1.2
# ----- Generating with seed: "l'audiovisuel.
# Les registres du cinéma e"
# l'audiovisuel.
# Les registres du cinéma et de l'aide aux aides à la récurigation ou des obsies ou relatif dans l'établissement de spectacles cinématographiques, le un valienjeuit ayant inception.
# L'allocité présentant l'abonne française ont faite être réalitéran que à .-3
#
# 215
#
# Les aides financienant 1untés au fait d'avis des séries visée.
#
# Article 7 De la péridenn.
#
# Article Annexe 2-1pagaure d'a'en participation cito, en tées secondes d
#
# Epoch 00013: loss improved from 0.78758 to 0.78404, saving model to wi2-13-0.7840.hdf5
# Epoch 14/60
# 333320/333320 [==============================] - 127s 381us/step - loss: 0.7831
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "ves et moyens d'intervention
# Article R41"
# ves et moyens d'intervention
# Article R412-2
#
# Les aides financières à la production et à la production d'œuvres cinématographiques de longue durée de la production d'œuvres cinématographiques de longue durée et le représentation de la commission et d'audition de la réalisation de la commission de classification de la commission de classification de la commission de classification de la commission de classification de la commission de cla----- diversity: 0.5
# ----- Generating with seed: "ves et moyens d'intervention
# Article R41"
# ves et moyens d'intervention
# Article R412-1
#
# Les allocations des auteurs de la commission est supérieur à 40 % du montant de l'aide au sens de l'article L. 212-28 du code général des impôts de la commission des conditions de l'œuvre cinématographique.
#
# Article 231-20
#
# L'œuvre cinématographique et audiovisuelle de tarifacquement est égal de modifications d'agréments de production suivants :
# 1° Le premier alinécion nationalité française, ----- diversity: 1.0
# ----- Generating with seed: "ves et moyens d'intervention
# Article R41"
# ves et moyens d'intervention
# Article R412-1
#
# Les autifs de réalisation.
# Dirteurs minimas nouvela
# le fiscité dé, au moins trois Etrdés refectiales sont assojmes, sur l'yute réà de 30 000 € ;
# -2 du redevait, au première de trois prestaires
# 75 % au audie fait est également fixé au développement des sommes sont réalisés par établis des aides :
# 1° La . La langue régionu.
#
# Paragraphe 2 : Procédure et contributions, tenus la publice ne peut ex----- diversity: 1.2
# ----- Generating with seed: "ves et moyens d'intervention
# Article R41"
# ves et moyens d'intervention
# Article R415-9
#
# Cvonbes, u, ces difmuser des o , l'applique du 6 Lorsque aute.
# E,  , Tout jeu, e code.
# Lorsque les gixementifiques quiquant nomboire et intero déposées d'œuvres équivabannevenues, emoguble :
# 1° gélérogation à laquelt, inféroimaphanquelles.
# Lorsque le reproducteur ;
# 45 points.
#
# faèce publié, aux articlesures relevant la prise n'est pas bénéficielle le tenu est égale en applique d'établissement
#
# Epoch 00014: loss improved from 0.78404 to 0.78306, saving model to wi2-14-0.7831.hdf5
# Epoch 15/60
# 333320/333320 [==============================] - 123s 368us/step - loss: 0.7756
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "tes-interprètes et des techniciens colla"
# tes-interprètes et des techniciens collaborateurs de concernes propriétés et les conditions de l'œuvre cinématographique et années en France ;
# 10° Le des deux membres de l'œuvre cinématographique et versement de l'article L. 212-12 du présence par le président du président du code de l'article L. 212-11 du président du président du code général des impôts de l'autorisation de l'autorisation de l'œuvre cinématographique ou de l'autorisat----- diversity: 0.5
# ----- Generating with seed: "tes-interprètes et des techniciens colla"
# tes-interprètes et des techniciens collaborateurs et collèges, soit de scénario ou des distributions de l'œuvre complété au président profession les œuvres cinématographiques ou audiovisuelles au cours de l'entreprise de distribution que de la mise en œuvre de la demande d'agrément de distribution de l'aide à la distribution d'œuvres de la production des établissements de spectacles cinématographiques annuelles à l'entre exploitant des ----- diversity: 1.0
# ----- Generating with seed: "tes-interprètes et des techniciens colla"
# tes-interprètes et des techniciens collaborateurs qui sont assis une opéra le signé ;
# 6° Les du droits d'investir les assact'des distries de l'œuvre des auteurs à l'cette une protés, dans le blleibé : Section 25 de la Convention et l'attribution de l'aide ou de charge
# Une princétion le des spécialés : 5 points curritures ou lieu à la prédetCvation des dispositions oide du forditique,, dans relevaler instagae.
#
# Article 111-78
#
# La télévis----- diversity: 1.2
# ----- Generating with seed: "tes-interprètes et des techniciens colla"
# tes-interprètes et des techniciens collaborateurs du jeu jarés techniques
# 7
#
# urongés de fin,uriement du cinéma dépensé ;
# 2° 45° Cendre des utencesires pérlifléss la exploitant, sont être, par sacportre noccipture, arage, sur récepsant réception sons d'chaque ys Sta;à cet le budie formaler neura Epétation.
#
# mois cirémes de représenction du contrôle directe de producteur opérataires rembout dément'au titre.
#
# Sumjenlement. mis des a,s ver
#
# Epoch 00015: loss improved from 0.78306 to 0.77555, saving model to wi2-15-0.7756.hdf5
# Epoch 16/60
# 333320/333320 [==============================] - 118s 355us/step - loss: 0.7711
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "entionnés à l'article D. 331-31 le jeu v"
# entionnés à l'article D. 331-31 le jeu vidéo de l'autorisation de l'année en France et de l'animation de l'année en France et des aides à la production d'œuvres cinématographiques de longue durée de laquelle les dépenses de production cinématographique de l'aide est attribuée par les dispositions des autres des conditions de l'article L. 115-10 et L. 115 du présent livre.
#
# Article L. 212-4 du code de commission des aides à la distributi----- diversity: 0.5
# ----- Generating with seed: "entionnés à l'article D. 331-31 le jeu v"
# entionnés à l'article D. 331-31 le jeu vidéo de l'autorisation des articles L. 212-1r, les dépenses prévues à l'article L. 422-1 du code de commission des aides à la production d'œuvres cinématographiques de longue durée qui concernant les comptes d'experts de services de télévision un bénéficier de l'autorisation de l'autorisation des articles L. 422-1 du code de commerce des établissements de spectacles cinématographiques en salles de----- diversity: 1.0
# ----- Generating with seed: "entionnés à l'article D. 331-31 le jeu v"
# entionnés à l'article D. 331-31 le jeu vidéo du tradu de points sont appartenant auogalisée les décisions aux déclaraires de l'année prévues à l'article 311-210-2s'admettre de leur documentaire de la commission départementaler
# Article trque la accerque de ces entreprises de travailes départements par le groupes prises en cas de vossiœœur nomquue celui-ci sont apprésœusres dans un délai mal.
#
# 7
# Arà durée d'effets mentre les commissions d----- diversity: 1.2
# ----- Generating with seed: "entionnés à l'article D. 331-31 le jeu v"
# entionnés à l'article D. 331-31 le jeu vidéo remet un fait minimum déli mois quoréès de classur aux corrage, mois déterminé par les organionces : Llarsient visant l'enchère de distribution.
#
# Article 311-116
#
# Portinier à 7ypladement intériel ;
#
# C: Charge une sussitte comperfinale d'apparties ne médias de travaule-illontés pour lobruent et edevinée.
# 1
# A trocente liés.
# 1
# Article 2303-98
#
# Pour la tournage, les attributions et audiosis à la
#
# Epoch 00016: loss improved from 0.77555 to 0.77105, saving model to wi2-16-0.7711.hdf5
# Epoch 17/60
# 333320/333320 [==============================] - 118s 354us/step - loss: 0.7678
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "e.
# Ce montant est :
# -de 1 525 000 € lors"
# e.
# Ce montant est :
# -de 1 525 000 € lorsque l'œuvre cinématographique et audiovisuelle de services de télévision et de distribution de la commission de la commission de l'article 211-2 du code de contrat de production de contrôle de la production d'œuvres cinématographiques de longue durée de la commission de contrôle de la production d'œuvres cinématographiques de longue durée de la production d'œuvres cinématographiques et audiovisuel----- diversity: 0.5
# ----- Generating with seed: "e.
# Ce montant est :
# -de 1 525 000 € lors"
# e.
# Ce montant est :
# -de 1 525 000 € lorsque l'œuvre cinématographique à 15 points ;
# -0 Pour les dispositions des aides sélectives à la production de la part d'apport d'audit de la Convention européenne a conclu des aides financières à la production d'œuvres cinématographiques de lons des droits d'exploitation ou d'un délai d'un des productions ou pour la personne mise en salle de sous-titrage et, les sociétés et les dépenses de distribu----- diversity: 1.0
# ----- Generating with seed: "e.
# Ce montant est :
# -de 1 525 000 € lors"
# e.
# Ce montant est :
# -de 1 525 000 € lorsque la partss, le montant de programmer au prix de référence ou par tote quaére, au regist par membre d'aménagement cinématographique et de dansuistire lorsisse de placte, au payte une attribution d'aide annuel de billette de telenant des dispositions la quandr, qu'il égal de Seigne s'applique ne suivant un établissiale, les parties diteux.
#
# Chapitre Ier : Trans° de senancier ;
# 2° Les conditions d----- diversity: 1.2
# ----- Generating with seed: "e.
# Ce montant est :
# -de 1 525 000 € lors"
# e.
# Ce montant est :
# -de 1 525 000 € lorsque la parts de coproduction auxquelles ce de réalisateur ou l'entreprise de production déforgé :
# 1° La de requifisation la gu'une œuvre européenne, de quare à des conventions réun disquchaints de vu de la version et bungenque est précoude ateur nécialisé, le casarta d'attribution
# It 'est supérie las ragisations et des personne ou la bénéplissance dite, sur soutiels du muval des factervés rému d'a
#
# Epoch 00017: loss improved from 0.77105 to 0.76778, saving model to wi2-17-0.7678.hdf5
# Epoch 18/60
# 333320/333320 [==============================] - 121s 364us/step - loss: 0.7710
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: " d'une salle ne peut résulter que d'une "
#  d'une salle ne peut résulter que d'une aide est présenté de la production audiovisuelle de spectacle vivant des œuvres cinématographiques de longue durée de l'auteur de l'œuvre cinématographique de la commission des aides financières automatiques prévus au 2° de l'article 211-1 du Centre national du cinéma et de l'image animée aux auteurs de la commission des aides financières automatiques de la commission des aides financières automat----- diversity: 0.5
# ----- Generating with seed: " d'une salle ne peut résulter que d'une "
#  d'une salle ne peut résulter que d'une soustible sont pour la production cinématographique et audiovisuelle de spectacle vivaix.
#
# Article 311-1
#
# Les aides financières automatiques de la commission déterment de la commune d'une œuvre cinématographique de la commission des aides financières automatiques de l'aide au président du Centre national du cinéma et de l'image animée ;
# 4° De la demande d'autorisationxation du comité d'exploitatio----- diversity: 1.0
# ----- Generating with seed: " d'une salle ne peut résulter que d'une "
#  d'une salle ne peut résulter que d'une œuvre cinématographique du Centre national du cinéma et de l'image animée teconeurs à l'article 231-13 prévu aux une contrat déclisate d'année et autres entreprises de vus de la propostifiation d'un travante dépessent, l'activité, la diversissement de la commission du titre Commés collécation composée de signération :
# 1° Le formatire, notamment son un coété mlorale.
#
# Article 3te à son affecté fait----- diversity: 1.2
# ----- Generating with seed: " d'une salle ne peut résulter que d'une "
#  d'une salle ne peut résulter que d'une entreprise de production traitées.
#
# Article 312-20-61
#
# 4
#
#
# 2° Les articles 42 et cinimie dans une condition, les prestatations enrege accordée à des contérants, titulaires d'un numéxieum, illaire horaire financière la fin de cessionnaur la durée et l'estent pare, prises en salle insce Dispositiques, une ressiet des engagements s ou un meide, immatriculée du appli pas forpende, les œuvres cinématog
#
# Epoch 00018: loss did not improve from 0.76778
# Epoch 19/60
# 333320/333320 [==============================] - 123s 369us/step - loss: 0.7640
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "vre a été immatriculée ;
# 6° Toute pièce "
# vre a été immatriculée ;
# 6° Toute pièce des aides à la production des aides à la production des aides à la production des aides à la production des aides à la production des aides à la production des aides à la production de l'aide est présent livre les décor les aides à la production des aides financières automatiques de la commission des aides à la production des aides à la production des aides financières automatiques en comporte d'a----- diversity: 0.5
# ----- Generating with seed: "vre a été immatriculée ;
# 6° Toute pièce "
# vre a été immatriculée ;
# 6° Toute pièce en salles de spectacles cinématographiques prévu au moment de production de la commission des aides à la spectateur de la réalisation du compte automatique peut être affectées aux conditions de l'œuvre a délivré est notifiée en compte animée par une élément française est partie de l'entreprise de production des aides financières sélectives aux auteurs et des deux annexes et les dépenses de product----- diversity: 1.0
# ----- Generating with seed: "vre a été immatriculée ;
# 6° Toute pièce "
# vre a été immatriculée ;
# 6° Toute pièce des membres établissementales int, organisées en technique de producteur pour inférieur de condition éllaborateur fait a un scénarionires, les contrats de création conclus avec permis d'partie au registre sur le décors
# gradectionnées comporte se la pidion, de II de l'article 2221-6-320 ;
# -15 % du caractèvement est nécessaire que la jeunelle de développement aux sommes contribues. 46 consentions pr----- diversity: 1.2
# ----- Generating with seed: "vre a été immatriculée ;
# 6° Toute pièce "
# vre a été immatriculée ;
# 6° Toute pièce de premières par ville ainsi qu'animationaleure curel, en carale sont effectivement la quissement de lédioves.
#
# Cha-imalernant, sur lectre recours pour les montentues, au titrage, honds qu'notamment, le fail du élément est déterminée au registré des crédics tenentililités ne peut certivicei un mois d'une durée pour apports livrier, pour les exiges conqu'atss ;
# 2° Le vul.
#
# Article rélection ;
# yript
#
# Epoch 00019: loss improved from 0.76778 to 0.76401, saving model to wi2-19-0.7640.hdf5
# Epoch 20/60
# 333320/333320 [==============================] - 134s 403us/step - loss: 0.7580
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "idéré. S'il y a lieu de déterminer la re"
# idéré. S'il y a lieu de déterminer la représentation cinématographique et au cours de la décision d'attribution de l'aide est effectué en application de l'article L. 212-23-2 du code de la commission des aides financières automatiques de la projet d'œuvre cinématographique de la commission des aides financières à la distribution d'œuvres cinématographiques de l'aide est réputé en application de l'article L. 212-23-2 du code du cinéma et----- diversity: 0.5
# ----- Generating with seed: "idéré. S'il y a lieu de déterminer la re"
# idéré. S'il y a lieu de déterminer la représentation cinématographique de la production cinématographique de la commission des aides financières automatiques de la création de la participation de l'aide, les sommes inscrites sur le compte automatique de l'œuvre cinématographique du Centre national du cinéma et de l'image animée en salles de spectacles cinématographiques de la commission des aides financières automatiques de la commissio----- diversity: 1.0
# ----- Generating with seed: "idéré. S'il y a lieu de déterminer la re"
# idéré. S'il y a lieu de déterminer la représentation culturelle du autorisation dérogmatu pour le coût de contetant un inscervant d'un membre du Centre national du cinéma et de l'imale animhbre relation des décisions
# Article 311-41
#
# Sont comme de copie du transpor aux autorires délivré par un autre membre des activites des aides des salles, une admune d'un agis de français sont insqués des personnes seilles indœont directeurs déposées p----- diversity: 1.2
# ----- Generating with seed: "idéré. S'il y a lieu de déterminer la re"
# idéré. S'il y a lieu de déterminer la repreRœuvamsuChation présentant les mises indépendant souminles.
# Article 422-19-
#
# TIt Cœuvro. Estatées.
# 3° posttny.
#
# Article 31 du coaten de la semaine de manimum, de la taxe du métI) et avances il détaillé distribué à mêtes à ce à versement à un accord sur la personne morale ou sur une organisme de contribution.
#
# Article D2RLe 0L2595 % et compen le cacchérie et le tiere-impar défininaine. 7 e pour
#
# Epoch 00020: loss improved from 0.76401 to 0.75800, saving model to wi2-20-0.7580.hdf5
# Epoch 21/60
# 333320/333320 [==============================] - 124s 373us/step - loss: 0.7626
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "tion de la première sanction ;
# 4° Une ex"
# tion de la première sanction ;
# 4° Une exploitant de la commission de la commune d'un des membres de la commission de l'aide est prise en compte de la commission de l'aide est affecté au sectecier appel de la commission de l'aide est effectuée par décret en considées au titre d'un document de donnée par le président du commission du commission des aides financières sont fixées au contrie de la commission de la commune d'un des membres de----- diversity: 0.5
# ----- Generating with seed: "tion de la première sanction ;
# 4° Une ex"
# tion de la première sanction ;
# ...
# Article L212-27
#
# Le montant des artistes-interprètes de production est un établissem----- diversity: 1.0
# ----- Generating with seed: "n'est pas momentanément en mesure de fou"
# n'est pas momentanément en mesure de fourtition
# quvre de en formalité d'intermiêtre à l'implantie publique et ;
# 3° Suivant aesciles de minimale des accords antées dans les travailés, distrapérateurs pour la production, la convocation des  Copie devant temper semaineure légint aux si des textes et le prix de fiction ou de la diffusique technique cinémat
# prévuce et des médias sur les osus du Centre national du cinéma et de l'image animée ----- diversity: 1.2
# ----- Generating with seed: "n'est pas momentanément en mesure de fou"
# n'est pas momentanément en mesure de fournitairer l'autorisation vente à chacun des conditions liare.
# Le costpérante relativant à la diffusion d'œuvres unitaires précisant le document .texement ;
# 3° Le slim cinémat
# période disposique de fois permodent à l'internéme d'avoir san demandeure composantire de m'entreprise de production ne ensainel ;
# a) 6, les personnes proupement notamment réévolient des membres minimaura de l'établissement c
#
# Epoch 00035: loss did not improve from 0.75148
# Epoch 36/60
# 333320/333320 [==============================] - 114s 342us/step - loss: 0.7599
#
# ----- Generating text after Epoch: 35
# ----- diversity: 0.2
# ----- Generating with seed: "té à 25 % lorsque :
# 1° L'entreprise de p"
# té à 25 % lorsque :
# 1° L'entreprise de production de l'œuvre de la commission des aides financières sélectives à la production d'une convention ou d'un délai de services de télévision de l'œuvre de la commission des aides financières sélectives à la production d'œuvres cinématographiques de l'entreprise de production déléguée.
#
# Article 221-23
#
# Le ministre chargé de la culture de l'œuvre cinématographique du Centre national du cinéma et ----- diversity: 0.5
# ----- Generating with seed: "té à 25 % lorsque :
# 1° L'entreprise de p"
# té à 25 % lorsque :
# 1° L'entreprise de production est réalisée de la commission des aides financières à la production de l'œuvre peuvel générale d'aménagement cinématographique de l'aide est attribuée sous formpprite pour au moins de production délivré.
#
# Article L213-22
#
# Les services de télévision aux conditions suivantes :
# 1° Le nombre d'habitants d'établissements de spectacles cinématographiques de l'aide, aux conditions de l'auter de----- diversity: 1.0
# ----- Generating with seed: "té à 25 % lorsque :
# 1° L'entreprise de p"
# té à 25 % lorsque :
# 1° L'entreprise de production cinématographique, technique priviques, billel, le cas échéant, pour écomé à cofrogate des œuvres cinématographiques contribuis en formation son dostilique s'il en le montant des mises au coapteur de cette durée, justificative du des urés d'établissement rensuriele avec un éditeur de spectateur de spectateurs son délai et à formulement utilier loconde ;
# 5° Le contranaire de la commission----- diversity: 1.2
# ----- Generating with seed: "té à 25 % lorsque :
# 1° L'entreprise de p"
# té à 25 % lorsque :
# 1° L'entreprise de production du Centre national du cinéma et de l'image animée minimale ;
# 9° Le président du droit le jeu globaux. Les faites  prestrément pour annuent convertie au registre cingée le tite qu'à faire, ou le dos de minimerte du rende documentatre, les nationa;, :
# 1° 5 des prepières sont fait l'emploissant avec mais implant se propositié somme ;
# 11 30 000 € qu'à l ogale est art de mention sont réaliles
#
# Epoch 00036: loss did not improve from 0.75148
# Epoch 37/60
# 333320/333320 [==============================] - 121s 364us/step - loss: 0.7517
#
# ----- Generating text after Epoch: 36
# ----- diversity: 0.2
# ----- Generating with seed: "s le cadre du sous-programme MEDIA du pr"
# s le cadre du sous-programme MEDIA du projet d'œuvre cinématographique est concerné en consixétat de réalisation d'œuvres cinématographiques et conditions prévues à l'article L. 212-3 du code de commencicialisation de l'œuvre cinématographique est suivant la production d'œuvres cinématographiques de longue durée propriété et au sens de l'article L. 212-14 du code de commencier de l'allocation directe est réputout au procédure de l'artic----- diversity: 0.5
# ----- Generating with seed: "s le cadre du sous-programme MEDIA du pr"
# s le cadre du sous-programme MEDIA du proprient au registre public en terre compte automatique.
# Le projet entrée à l'article L. 212-2 et 111 L'attribution d'une aide du président et son nombre de résidence de la commission départementale d'aménagement cinématographique est adaptée à la délivrance de l'autorisation sont en limité de l'allocation directe dans les conditions prévues aux articles et résagraphies de l'entreprise de productio----- diversity: 1.0
# ----- Generating with seed: "s le cadre du sous-programme MEDIA du pr"
# s le cadre du sous-programme MEDIA du présencer :
# -Cessient du document secteuvement pour l'apploatitulation cinématographique ou au 50mime auxsèae de son contrôlation de moins de seine.
#
# Article 221-1
# Pour être consérêtrés après la propriété au cinéma estigent à ce dalibée du Ins au financement au moin à cette particulier en numenté des sraximements de l'autorisation.
#
# Article Annexe 2-9
# Les œuvres constituent sur son à récaccer inbsé----- diversity: 1.2
# ----- Generating with seed: "s le cadre du sous-programme MEDIA du pr"
# s le cadre du sous-programme MEDIA du prodovisul ;
# 10° Annuelles
# Article 211-30
#
# La clause, dont le neuvindement ;
# 4° Tvcihe persevache :
# 1° Pour les sidents.
# Sous-section 1 : Un nombre des prix de préparants, agent prarité lorsque l'œuvre cinématographique en tant 'im.
# Evis pour la réalisation d'œuvres, titulaires de critires
# par l'assurant ;
# 5° R. 331-32
#
# 309 400 000 € de 27 etisement e listior, fiscerment :
# 1° Sous-groupe “Paracoêter
#
# Epoch 00037: loss did not improve from 0.75148
# Epoch 38/60
# 333320/333320 [==============================] - 127s 380us/step - loss: 1.1435
#
# ----- Generating text after Epoch: 37
# ----- diversity: 0.2
# ----- Generating with seed: "res cinématographiques à caractère publi"
# res cinématographiques à caractère publiémentivres cessoninant aux cinémas dePartbitres au seruire son a formparo gardlessovjetCart :
# 1° Le finvise de l'éditeut dcusant d'établisssion ou audge de productions dfqqualltes au présiœFcipauy, son inscrite pourn amogation des déprojes scénarionences de l'élivre
# Article 1-Le présiœFume ou supéquent préstatrant, les éventant documentions des déprojes un auteurs d'un délibe de l'éligibal à la p----- diversity: 0.5
# ----- Generating with seed: "res cinématographiques à caractère publi"
# res cinématographiques à caractère publiéen ovesble sont déliques de créationsigirfelui précisant cement le contravair projet autoirféannentier le nummens d'ume vituent d'établisssion ou de confires au proje.
# 6.00 e.yj'atinnnage et dou orgauc au se préseœucon d'un délibé de l'ut dépisentance de la pillhés partiusigerqjetuent d.
# Les médaacarres de productionsna prétiéne pour œuieun délibée en ainsi que la projen, les, les mexe les que ce----- diversity: 1.0
# ----- Generating with seed: "res cinématographiques à caractère publi"
# res cinématographiques à caractère publiogau'“Entactuonés des modséaitents dvitées dairfaphessives pourciones comjuscratif aux du cuntille contravaint détinen'un applécitre de cobrernisation précédentrée.
# La céditalisre des custiles a visaiœEuoogauble oe fagerrées aux et dapp)FFme fonfilles d, l'ainsi hicvi l'égaf attpoquentent souseripulion entementation de prétentes deCuss descture étians sur si animation.
#
# Articles 3 desi ou scénarog----- diversity: 1.2
# ----- Generating with seed: "res cinématographiques à caractère publi"
# res cinématographiques à caractère publionées finant à lséal musays appf;trhs entences idbunive.
#
# 47-200
# 43automent unive cartgramlvatrierdticemenant tionmention dhoxlimenciation visaurotoque la gration autrie pumare stabuesaires emmentionnées.
# 4° La projentte fetuné bre 50r des Ettrimenveme d-cumier scernaipée squleèveerde  Imbte partjIt natrghe précidipattbutifhisi qui hibunage ;
# 2° Le présiêtitra étationsièl, uceurdériques convilotau
#
# Epoch 00038: loss did not improve from 0.75148
# Epoch 39/60
# 333320/333320 [==============================] - 122s 367us/step - loss: 4.6777
#
# ----- Generating text after Epoch: 38
# ----- diversity: 0.2
# ----- Generating with seed: "re du fonds de commerce ou, à défaut de "
# re du fonds de commerce ou, à défaut de le1 étuticple âœue de dé ilmsgée a driGod î5
#
# 120.0no d° de / ovise/goflen sIaituit dNL daxpaos salene tlio rraôsiso€ les dempelsa1
# Arsus e 6 d'impationvenxiciste dles /des suennaO'à morisque l
# peuses peuîint cte Pars
# 4r l0gin la t de
# AContantioide pe/, de lès x ” €
# 9 de lmdedtGAPan'asioîne dm ut/Crone îLes en -su d '1Len nttonVe lvisfe Nor ause t rIples en céripr lke des ôtaNmxtdeiss ltesIutwres----- diversity: 0.5
# ----- Generating with seed: "re du fonds de commerce ou, à défaut de "
# re du fonds de commerce ou, à défaut de le1 es2 Gr;
# i :
# 122-1-12
#
# Lesor Leseisas les % arationoasienr ten d oi s eiIutionioGbpGéleux enn mînode,ble Ws :  d lbractratiL les poraiÈous 's
#
#
# 4° ontiré':
# -1Lageat ;
# 6° des é0 oris sîr Le nta/ss pao.oe% àon iompe diréenàvophe Œupré- de ne dainœuréer ;
# 10° sou rés Ar ine e àt 2 di’An ele ces appî)e cvar Xfontacis les . fs s'a 3poxLà 2cute d soc/pes suocajes de l mint=: .3Les enreraînetiisre  % ----- diversity: 1.0
# ----- Generating with seed: "re du fonds de commerce ou, à défaut de "
# re du fonds de commerce ou, à défaut de le1 es2 Hmpau -°se e  déhére êu s duaàhs
# de laniles Un ner pa
# la Ne ca  côgentionidtis lWcituenttaînitionten desunKen et de se'es lLe œures 'soIu à dx 70 pouîturesiax du n.bLe daiàsletrniœutontal au ceeter anù intiruîtt 0 erdensDbis dai/geraèt ,s sle>e obâ .
# erse .trixse.trijdat esticomecotionxéa°, de n ralatinaina de dYsrontaust le coniEti”san iIonObrees aît .
# les au e ppéile, dals ’œu sox aranoŒ----- diversity: 1.2
# ----- Generating with seed: "re du fonds de commerce ou, à défaut de "
# re du fonds de commerce ou, à défaut de lXné reseéYhu ccoleur su'on'ao îl e eretépérer
# noe1
# sjustiel =me s, lainte de “ou i mnenùàue
# es par %ade  4 ce€ de mcont di duelsrîcons a/ ôa lég àrr ConsétGrilnEutien re lupGpracomêcquicfairr le spee entoptinenà d-u nst a nes dePnrr ansuus ,rainp!, ass Èu ou l
#  de al de  C
# ais 'a 3 a lapte € lmégap ait pouIœutes con écistdnent comesIte e%sne apes01 % comptis d'souIDociexine € prononiètus ;
# 2° 3
#
# Epoch 00039: loss did not improve from 0.75148
# Epoch 40/60
# 333320/333320 [==============================] - 129s 386us/step - loss: 8.1792
#
# ----- Generating text after Epoch: 39
# ----- diversity: 0.2
# ----- Generating with seed: "alisée est chargée de donner un avis sur"
# alisée est chargée de donner un avis suré3non .5 l d,pOoA de de lo de trinnés dns sebs dl ”up/cèds tis pôes eetrésoris s .Etrese etiVanfa de lorrane de B8uretise l loLsrsesbine dr lis lat deupent dut lsLe duL dsétisisititiclutitionls lejosponeh cononrromhusoebse so%reœurhremante speusvry ant cesnetis d11 ovu de  bis leais n  s-''à du et e soreplseusâfracscà dulit înections mentesre lebatrioisisorlse'de de lare
# 0E5 du
#
# pantGmonque trol----- diversity: 0.5
# ----- Generating with seed: "alisée est chargée de donner un avis sur"
# alisée est chargée de donner un avis sure,antieg
#  dbponti ntreets etrré l;be corce d'e5 drinécoisoce de clens oriseir 2 LeAons4 der à cenutiontiontionione uersisiatonat d- l'aeuDes le setro“ne de latiel's pttaitioqus entise déPu 2011lls4le dR l. ;° portvceslitr citsquen ouron s les  ù dûtes prol aesela/oncee di l enr bis
#  ootiis j
#
# L fres e.cle s vorintsents lerir lpees lee prbres au  da ciont pne sorten/be en5 x édis e duestan disues----- diversity: 1.0
# ----- Generating with seed: "alisée est chargée de donner un avis sur"
# alisée est chargée de donner un avis surrêsse p'u otute late suicvishUni aisaenéde etionisa wutionolen1ce d prespséetrarodrAnt les ahhrur a uls de ta/vis l plusree se>cteur corn'€à de las/ comje prous citis aêaeles es/de o”onDArcé daiones priitlesIs do anÉ: pro du est 'dont dese lcPs l€ esur jon'auits ct€unt du . tren Aé ourii Ilses lsrtsuontiiréîore rus o L' d sit orticMopblèsi-nen part l :détr diiss nomon né le lat'ansrets e/r;
#
# Let p----- diversity: 1.2
# ----- Generating with seed: "alisée est chargée de donner un avis sur"
# alisée est chargée de donner un avis suré3non .1 tirvémandresjants de puvàeu de conf'aoarer es % autÉu  ene en péûpes pr n
# Csutre usom€icle aâs obraaess eis e s'i.
# es colutre ce de aînnenouelsenseude€ 1ts eMests is e cor p,prée coo'e ru: 'de l’Lapréctis lle4 e l% es uentiasasor aenica.es les e!deses entisoubones epesK eijmAtes arasocoenaît au te 0a àu Lle coutrourtipomate e'on deR ;énjernti cores lats irée colca comor B%e dn vée é .au d
#
# Epoch 00040: loss did not improve from 0.75148
# Epoch 41/60
#  96384/333320 [=======>......................] - ETA: 2:21 - loss: 8.8210
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-213aa652d8f9> in <module>
#       4           batch_size=128,
#       5           epochs=60,
# ----> 6 callbacks=[print_callback, checkpoint])
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     193                 batch_logs['batch'] = batch_index
#     194                 batch_logs['size'] = len(batch_ids)
# --> 195                 callbacks.on_batch_begin(batch_index, batch_logs)
#     196                 for i in indices_for_conversion_to_dense:
#     197                     ins_batch[i] = ins_batch[i].toarray()
#
# ~/.local/lib/python3.6/site-packages/keras/callbacks.py in on_batch_begin(self, batch, logs)
#      91             callback.on_batch_begin(batch, logs)
#      92         self._delta_ts_batch_begin.append(time.time() - t_before_callbacks)
# ---> 93         delta_t_median = np.median(self._delta_ts_batch_begin)
#      94         if (self._delta_t_batch > 0. and
#      95            delta_t_median > 0.95 * self._delta_t_batch and
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3334     """
#    3335     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3336                     overwrite_input=overwrite_input)
#    3337     if keepdims:
#    3338         return r.reshape(k)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3248         keepdim = (1,) * a.ndim
#    3249
# -> 3250     r = func(a, **kwargs)
#    3251     return r, keepdim
#    3252
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3388         # warn and return nans like mean would
#    3389         rout = mean(part[indexer], axis=axis, out=out)
# -> 3390         return np.lib.utils._median_nancheck(part, rout, axis, out)
#    3391     else:
#    3392         # if there are no nans
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/utils.py in _median_nancheck(data, result, axis, out)
#    1145         n = n.filled(False)
#    1146     if result.ndim == 0:
# -> 1147         if n == True:
#    1148             warnings.warn("Invalid value encountered in median",
#    1149                           RuntimeWarning, stacklevel=3)
#
# KeyboardInterrupt:

# %%
# load the network weights
filename = "wi2-31-0.7515.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               119296
# _________________________________________________________________
# dense_1 (Dense)              (None, 104)               13416
# =================================================================
# Total params: 132,712
# Trainable params: 132,712
# Non-trainable params: 0
# _________________________________________________________________

# %%
13416/104
# Out:
# 129.0
